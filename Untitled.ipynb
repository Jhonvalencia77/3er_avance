# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame
import csv
import pickle

# %%
with open('/home/jonathan/tesis/3er_avance/columns_names.pickle', "rb") as file:   
    columns_names = pickle.load(file)

names = list(columns_names)
lista=["ds"]
    
for trayectos in names:    
    x=trayectos.startswith("2807901")    
    if x==True:                         
        lista.append(trayectos)

df = pd.read_csv("/home/jonathan/tesis/3er_avance/Trayectos_Periodo_Referencia.csv", sep=',',index_col=0, parse_dates=True, usecols=lista)
df.head(10)
# Out:
#                      2807901-01036  2807901-0105901  2807901-0105902  \
# ds
# 2020-02-14 00:00:00          0.000              0.0              0.0
# 2020-02-14 01:00:00          0.000              0.0              0.0
# 2020-02-14 02:00:00          0.000              0.0              0.0
# 2020-02-14 03:00:00          0.000              0.0              0.0
# 2020-02-14 04:00:00          0.000              0.0              0.0
# 2020-02-14 05:00:00          0.000              0.0              0.0
# 2020-02-14 06:00:00          0.000              0.0              0.0
# 2020-02-14 07:00:00          0.000              0.0              0.0
# 2020-02-14 08:00:00          0.000              0.0              0.0
# 2020-02-14 09:00:00          4.576              0.0              0.0
#
#                      2807901-0105903  2807901-0200301  2807901-0200302  \
# ds
# 2020-02-14 00:00:00              0.0            0.000            6.227
# ...

# %%
df.iloc[:,500:1000]
# Out:
#                      2807901-2807916  2807901-2807917  2807901-2807918  \
# ds
# 2020-02-14 00:00:00          326.153          382.250          197.378
# 2020-02-14 01:00:00          231.128          253.146          115.254
# 2020-02-14 02:00:00          113.793          171.398           90.938
# 2020-02-14 03:00:00           85.670           83.062           79.471
# 2020-02-14 04:00:00          112.409          114.426           85.345
# ...                              ...              ...              ...
# 2020-03-16 19:00:00           67.111           86.640           70.342
# 2020-03-16 20:00:00           54.279           95.071           61.083
# 2020-03-16 21:00:00           41.011           91.040           65.120
# 2020-03-16 22:00:00           32.982           83.084           70.765
# 2020-03-16 23:00:00           11.669           41.755           31.681
#
#                      2807901-2807919  2807901-2807920  2807901-2807921  \
# ds
# ...

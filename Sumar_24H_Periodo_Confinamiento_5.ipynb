# %%
import pandas as pd
import numpy as np
import pickle

# %%
basepath = "/media/jonathan/JHON/Tesis/DatosTesis/CSV_Filtrado_Origen/DataFiltradoFebrero2021_1.csv"
data = pd.read_csv(basepath, sep=',',dtype={"fecha": str,
                                        "origen": str,
                                        "destino": str},index_col='fecha',parse_dates=True, usecols=[0,1,2,7,8,9])          

data = data[data.distancia >= "002-005"]

################3

basepath = "/media/jonathan/JHON/Tesis/DatosTesis/CSV_Filtrado_Origen/DataFiltradoFebrero2021_2.csv"
data2 = pd.read_csv(basepath, sep=',',dtype={"fecha": str,
                                        "origen": str,
                                        "destino": str},index_col='fecha',parse_dates=True, usecols=[0,1,2,7,8,9])          

data2 = data2[data2.distancia >= "002-005"]

#################

basepath = "/media/jonathan/JHON/Tesis/DatosTesis/CSV_Filtrado_Origen/DataFiltradoMarzo2021_1.csv"
data3 = pd.read_csv(basepath, sep=',',dtype={"fecha": str,
                                        "origen": str,
                                        "destino": str},index_col='fecha',parse_dates=True, usecols=[0,1,2,7,8,9])          

data3 = data3[data3.distancia >= "002-005"]

#################

basepath = "/media/jonathan/JHON/Tesis/DatosTesis/CSV_Filtrado_Origen/DataFiltradoMarzo2021_2.csv"
data4 = pd.read_csv(basepath, sep=',',dtype={"fecha": str,
                                        "origen": str,
                                        "destino": str},index_col='fecha',parse_dates=True, usecols=[0,1,2,7,8,9])          

data4 = data4[data4.distancia >= "002-005"]

##################

basepath = "/media/jonathan/JHON/Tesis/DatosTesis/CSV_Filtrado_Origen/DataFiltradoAbril2021_1.csv"
data5 = pd.read_csv(basepath, sep=',',dtype={"fecha": str,
                                        "origen": str,
                                        "destino": str},index_col='fecha',parse_dates=True, usecols=[0,1,2,7,8,9])          

data5 = data5[data5.distancia >= "002-005"]

##################

basepath = "/media/jonathan/JHON/Tesis/DatosTesis/CSV_Filtrado_Origen/DataFiltradoAbril2021_2.csv"
data6 = pd.read_csv(basepath, sep=',',dtype={"fecha": str,
                                        "origen": str,
                                        "destino": str},index_col='fecha',parse_dates=True, usecols=[0,1,2,7,8,9])          

data6 = data6[data6.distancia >= "002-005"]

##################

basepath = "/media/jonathan/JHON/Tesis/DatosTesis/CSV_Filtrado_Origen/DataFiltradoMayo2021_1.csv"
data7 = pd.read_csv(basepath, sep=',',dtype={"fecha": str,
                                        "origen": str,
                                        "destino": str},index_col='fecha',parse_dates=True, usecols=[0,1,2,7,8,9])          

data7 = data7[data7.distancia >= "002-005"]
data7.head(5)
# Out:
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024   0200301        9      100+  15.886
# 2021-05-01  19024  02069_AM       19      100+   7.466
# 2021-05-01  19024  02069_AM       20      100+   7.466
# 2021-05-01  19024   0905905        4      100+   8.682
# 2021-05-01  19024     12028        5      100+   6.862

# %% [markdown]
# ## Debido a que se tiene como destino toda España, se procede a filtrar la columna destino

# %%
columnas=["19024","19046_AM","19053_AM","19058_AM","19071_AM","19086_AM","1913001","1913002","1913003","1913004","1913005","19151_AM","19156_AM","19160_AM","19171","19190_AM","19192_AM","19220_AM","19245_AM","19257_AM","19274_AM","19280_AM","19319","19326_AM","19331_AM","28002","28004","2800501","2800502","2800503","2800504","2800505","2800601","2800701","2800702","2800703","2800704","28008_AM","28009","28010","2801301","2801302","2801303","2801304","28014","28015","28018","28022","28023","28026","28027_AM","28030_AM","28031_AM","28032_AM","28033","28038_AM","28040","28041","28043","28044","28045","28046","28047","2804901","2804902","2804903_AD","28050_AM","28052_AM","28053","28054","2805801","2805802","2805803","2805804","2805805","2805806","2805807","2805808","2805809","28059","28060_AM","28061","2806501","2806502","2806503","2806504","28066","28067_AM","28068","28072","28073","2807401","2807402","2807403","2807404","2807405","2807406","2807407","28075","2807901","2807902","2807903","2807904","2807905","2807906","2807907","2807908","2807909","2807910","2807911","2807912","2807913","2807914","2807915","2807916","2807917","2807918","2807919","2807920","2807921","2808001","2808002","28082","28083","28084","28085_AM","28086","28087","28089","28090","28091","2809201","2809202","2809203","2809204","28095_AM","28096","28099_AM","28100","28104","2810601","28108","28110_AM","2811301","2811302","2811501","2811502","28119_AM","2812301","28125_AM","2812701","28129","28130","28131","28132","28133_AM","2813401","28137_AM","28140_AM","28141","28144","28145_AM","2814801","2814802","2814803","2814804","28149","28150","28151_AM","28152","28154","28160","2816101","2816102","28162_AM","28164","28165_AM","28167","28171","28172","28176","28177","28180","28181","28901_AM","28903"]
filtrado_Data = pd.DataFrame({})
filtrado_Data2 = pd.DataFrame({})
filtrado_Data3 = pd.DataFrame({})
filtrado_Data4 = pd.DataFrame({})
filtrado_Data5 = pd.DataFrame({})
filtrado_Data6 = pd.DataFrame({})
filtrado_Data7 = pd.DataFrame({})
for col in columnas:
        filtrar = data.loc[data.loc[:,'destino'] == col]
        filtrar2 = data2.loc[data2.loc[:,'destino'] == col]
        filtrar3 = data3.loc[data3.loc[:,'destino'] == col]
        filtrar4 = data4.loc[data4.loc[:,'destino'] == col]
        filtrar5 = data5.loc[data5.loc[:,'destino'] == col]
        filtrar6 = data6.loc[data6.loc[:,'destino'] == col]
        filtrar7 = data7.loc[data7.loc[:,'destino'] == col]
        print(filtrar7.head(3))
        filtrado_Data=filtrado_Data.append(filtrar)
        filtrado_Data2=filtrado_Data2.append(filtrar2)
        filtrado_Data3=filtrado_Data3.append(filtrar3)
        filtrado_Data4=filtrado_Data4.append(filtrar4)
        filtrado_Data5=filtrado_Data5.append(filtrar5)
        filtrado_Data6=filtrado_Data6.append(filtrar6)
        filtrado_Data7=filtrado_Data7.append(filtrar7)
# Out:
#            origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024   19024        0   002-005   6.871
# 2021-05-01  19024   19024        3   002-005   6.871
# 2021-05-01  19024   19024        6   002-005   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19046_AM        0   002-005  13.742
# 2021-05-01  19024  19046_AM        0   005-010  13.742
# 2021-05-01  19024  19046_AM        1   002-005  13.742
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19053_AM       12   010-050   6.871
# 2021-05-01  19024  19053_AM        9   010-050  10.075
# 2021-05-01  19024  19053_AM       10   010-050   6.249
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19058_AM        0   002-005  61.839
# 2021-05-01  19024  19058_AM        0   005-010  27.484
# 2021-05-01  19024  19058_AM        1   002-005  20.613
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19071_AM       18   010-050   6.871
# 2021-05-01  19024  19071_AM       22   010-050   8.206
# 2021-05-01  19024  19071_AM       23   010-050   8.206
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19086_AM       10   050-100   6.871
# 2021-05-01  19024  19086_AM       11   050-100  20.613
# 2021-05-01  19024  19086_AM       16   050-100   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen  destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  1913001        0   010-050   6.871
# 2021-05-01  19024  1913001        3   005-010   6.871
# 2021-05-01  19024  1913001        5   005-010   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen  destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  1913002       10   005-010  20.613
# 2021-05-01  19024  1913002       11   005-010   6.871
# 2021-05-01  19024  1913002       12   005-010   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen  destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  1913003        1   005-010   6.871
# 2021-05-01  19024  1913003        4   005-010   6.871
# 2021-05-01  19024  1913003        6   005-010  13.742
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen  destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  1913004        1   005-010   6.871
# 2021-05-01  19024  1913004        7   005-010   6.871
# 2021-05-01  19024  1913004        9   005-010   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen  destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  1913005        2   005-010   6.871
# 2021-05-01  19024  1913005        5   005-010   6.871
# 2021-05-01  19024  1913005        6   005-010  13.742
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19151_AM        7   010-050   6.871
# 2021-05-01  19024  19151_AM        8   050-100   6.871
# 2021-05-01  19024  19151_AM       10   010-050   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01     19024  19156_AM        8   050-100   6.871
# 2021-05-01     19024  19156_AM        8   050-100   8.043
# 2021-05-01  19046_AM  19156_AM        8   050-100   8.043
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19160_AM       10   010-050   6.871
# 2021-05-01  19024  19160_AM       12   010-050   6.871
# 2021-05-01  19024  19160_AM       15   010-050   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024   19171        1   010-050   6.871
# 2021-05-01  19024   19171        4   005-010   6.871
# 2021-05-01  19024   19171        5   005-010   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19046_AM  19190_AM       13      100+  19.451
# 2021-05-01  19053_AM  19190_AM       11   050-100  19.451
# 2021-05-01  19053_AM  19190_AM       17   050-100   7.470
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19192_AM        9   010-050   6.871
# 2021-05-01  19024  19192_AM       11   050-100   6.871
# 2021-05-01  19024  19192_AM        9   010-050  11.769
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19220_AM       13   010-050   6.871
# 2021-05-01  19024  19220_AM        7   010-050   7.351
# 2021-05-01  19024  19220_AM       12   010-050   7.351
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19245_AM        7   050-100  13.742
# 2021-05-01  19024  19245_AM        9   050-100   6.871
# 2021-05-01  19024  19245_AM       10   050-100   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01     19024  19257_AM       11   050-100  15.810
# 2021-05-01  19046_AM  19257_AM       10   050-100  16.086
# 2021-05-01  19046_AM  19257_AM       11   050-100  32.172
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19274_AM       17   010-050   6.871
# 2021-05-01  19024  19274_AM        6   010-050   7.591
# 2021-05-01  19024  19274_AM       14   010-050   6.161
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19280_AM       13   005-010   6.871
# 2021-05-01  19024  19280_AM       13   010-050   6.871
# 2021-05-01  19024  19280_AM       17   010-050   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024   19319        0   002-005   6.871
# 2021-05-01  19024   19319        1   002-005  13.742
# 2021-05-01  19024   19319        2   002-005   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19326_AM        9   010-050   6.871
# 2021-05-01  19024  19326_AM       10   010-050   6.871
# 2021-05-01  19024  19326_AM       11   010-050   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024  19331_AM        9   010-050   6.871
# 2021-05-01  19024  19331_AM       13   010-050   6.871
# 2021-05-01  19024  19331_AM       16   010-050   6.871
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19046_AM   28002        8   010-050   9.855
# 2021-05-01  19046_AM   28002       10   010-050   9.855
# 2021-05-01  19046_AM   28002        7   010-050   9.855
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  28004   28004        0   002-005  21.552
# 2021-05-01  28004   28004       18   002-005  21.552
# 2021-05-01  28004   28004       20   002-005  10.776
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  28004   28171       13   010-050  10.776
# 2021-05-01  28004   28171       13   010-050   8.338
# 2021-05-01  28004   28171       12   010-050   8.938
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19024   28172        5   010-050   7.943
# 2021-05-01  19024   28172       14   010-050   7.943
# 2021-05-01  19024   28172       19   010-050  13.156
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19190_AM   28176       22      100+   9.274
# 2021-05-01  19245_AM   28176       14      100+   9.274
# 2021-05-01     28002   28176        7   010-050   7.314
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19245_AM   28177       17      100+  20.463
# 2021-05-01     19319   28177       10   050-100   8.588
# 2021-05-01   2800504   28177       11   010-050  17.588
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19046_AM   28180       11   010-050  10.204
# 2021-05-01  19071_AM   28180        7   050-100  10.096
# 2021-05-01  19160_AM   28180       15   010-050  10.204
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#            origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19171   28181       11   050-100   6.862
# 2021-05-01  28004   28181       14   010-050  10.776
# 2021-05-01  28004   28181       16   005-010  10.776
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen   destino  periodo distancia  viajes
# fecha
# 2021-05-01  19046_AM  28901_AM       11   050-100   9.855
# 2021-05-01  19058_AM  28901_AM       15   010-050   6.467
# 2021-05-01  19058_AM  28901_AM       17   010-050   6.467
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)
#               origen destino  periodo distancia  viajes
# fecha
# 2021-05-01  19046_AM   28903       12   010-050   8.924
# 2021-05-01  19071_AM   28903        4   010-050  10.096
# 2021-05-01  19071_AM   28903       17   010-050  10.096
# /tmp/ipykernel_22315/293907508.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data=filtrado_Data.append(filtrar)
# /tmp/ipykernel_22315/293907508.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data2=filtrado_Data2.append(filtrar2)
# /tmp/ipykernel_22315/293907508.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data3=filtrado_Data3.append(filtrar3)
# /tmp/ipykernel_22315/293907508.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data4=filtrado_Data4.append(filtrar4)
# /tmp/ipykernel_22315/293907508.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data5=filtrado_Data5.append(filtrar5)
# /tmp/ipykernel_22315/293907508.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data6=filtrado_Data6.append(filtrar6)
# /tmp/ipykernel_22315/293907508.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtrado_Data7=filtrado_Data7.append(filtrar7)

# %%
#filtrado.dtypes
filtrado_Data6.shape
# Out:
# (7286447, 5)

# %%
filtrado_Data7.shape
# Out:
# (4371123, 5)

# %%
filtrado_Data.index.freq = filtrado_Data.index.inferred_freq
serieDia = filtrado_Data.resample('24H').sum()
serieDia.index

filtrado_Data2.index.freq = filtrado_Data2.index.inferred_freq
serieDia2 = filtrado_Data2.resample('24H').sum()
serieDia2.index

filtrado_Data3.index.freq = filtrado_Data3.index.inferred_freq
serieDia3 = filtrado_Data3.resample('24H').sum()
serieDia3.index

filtrado_Data4.index.freq = filtrado_Data4.index.inferred_freq
serieDia4 = filtrado_Data4.resample('24H').sum()
serieDia4.index

filtrado_Data5.index.freq = filtrado_Data5.index.inferred_freq
serieDia5 = filtrado_Data5.resample('24H').sum()
serieDia5.index

filtrado_Data6.index.freq = filtrado_Data6.index.inferred_freq
serieDia6 = filtrado_Data6.resample('24H').sum()
serieDia6.index

filtrado_Data7.index.freq = filtrado_Data7.index.inferred_freq
serieDia7 = filtrado_Data7.resample('24H').sum()
serieDia7.index
# Out:
# DatetimeIndex(['2021-05-01', '2021-05-02', '2021-05-03', '2021-05-04',
#                '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-08',
#                '2021-05-09'],
#               dtype='datetime64[ns]', name='fecha', freq='24H')

# %%
filtrado_Data['trayecto'] = filtrado_Data['origen'] + '-' + filtrado_Data['destino']
filtrado_Data2['trayecto'] = filtrado_Data2['origen'] + '-' + filtrado_Data2['destino']
filtrado_Data3['trayecto'] = filtrado_Data3['origen'] + '-' + filtrado_Data3['destino']
filtrado_Data4['trayecto'] = filtrado_Data4['origen'] + '-' + filtrado_Data4['destino']
filtrado_Data5['trayecto'] = filtrado_Data5['origen'] + '-' + filtrado_Data5['destino']
filtrado_Data6['trayecto'] = filtrado_Data6['origen'] + '-' + filtrado_Data6['destino']
filtrado_Data7['trayecto'] = filtrado_Data7['origen'] + '-' + filtrado_Data7['destino']
filtrado_Data7.head(5)
# Out:
#            origen destino  periodo distancia  viajes     trayecto
# fecha
# 2021-05-01  19024   19024        0   002-005   6.871  19024-19024
# 2021-05-01  19024   19024        3   002-005   6.871  19024-19024
# 2021-05-01  19024   19024        6   002-005   6.871  19024-19024
# 2021-05-01  19024   19024        7   002-005  13.742  19024-19024
# 2021-05-01  19024   19024       12   002-005  20.613  19024-19024

# %%
df_Total = pd.DataFrame({})
reindex=filtrado_Data.reset_index()  #Solo cambiamos esta linea

for fecha in serieDia.index:   
    filtrar = reindex.loc[reindex.loc[:,'fecha'] == fecha]
    print(filtrar.shape)
    table_A = pd.pivot_table(filtrar, values=['viajes','origen','destino','fecha'], index=["periodo","trayecto"], aggfunc={'viajes':np.sum,'origen': 'first','destino': 'first','fecha': 'first'})
    reindex2 = table_A.reset_index()
    table_B = pd.pivot_table(reindex2, values=['viajes'], index=["periodo"], columns=["trayecto"], aggfunc={'viajes':'first'}, fill_value=0)
    print(table_A.shape)
    print(table_B.shape)
    
    if table_B.index.shape[0] != 24:
        j = 0
        for i in range(24):
            if table_B.index[i] != (i+j):
                print (reindex.fecha.iloc[0],i+j,"origen sin registros!")
                table_B.loc[i+j] = 0
                j += 1
            if (i + j) == 23: break
        table_B = table_B.sort_index() 
    
    table_B["ds"] = pd.date_range(filtrar.fecha.iloc[0], "%s 23:00:00" % (filtrar.fecha.iloc[0]), freq="H")  #fecha.iloc[0] devuelve "20200214"-"20200215"... y la hora en formato 24h      
    table_B = table_B.set_index("ds") #Fija como indice la columna ds           
    table_B = table_B.astype(np.float32)
    
    df_Total = df_Total.append(table_B)
    df_Total = df_Total.fillna(0)       
    #break
print(df_Total.shape)
# Out:
# (518944, 7)
# (184841, 4)
# (24, 22070)
# (538048, 7)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (189724, 4)
# (24, 22303)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (542073, 7)
# (190839, 4)
# (24, 22504)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (547249, 7)
# (191996, 4)
# (24, 22543)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (539278, 7)
# (190558, 4)
# (24, 22567)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (371002, 7)
# (146711, 4)
# (24, 19473)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (326851, 7)
# (134650, 4)
# (24, 19051)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (534156, 7)
# (188700, 4)
# (24, 22294)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (546354, 7)
# (191172, 4)
# (24, 22308)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (559128, 7)
# (194883, 4)
# (24, 22717)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (557115, 7)
# (195021, 4)
# (24, 22849)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (541530, 7)
# (191641, 4)
# (24, 22631)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (398425, 7)
# (158599, 4)
# (24, 20968)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (349628, 7)
# (144026, 4)
# (24, 20039)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (538833, 7)
# (190909, 4)
# (24, 22619)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (556069, 7)
# (195241, 4)
# (24, 22900)
# /tmp/ipykernel_22315/1544190192.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (384, 31579)

# %%
reindex=filtrado_Data2.reset_index()

for fecha in serieDia2.index:   
    filtrar = reindex.loc[reindex.loc[:,'fecha'] == fecha]
    print(filtrar.shape)
    table_A = pd.pivot_table(filtrar, values=['viajes','origen','destino','fecha'], index=["periodo","trayecto"], aggfunc={'viajes':np.sum,'origen': 'first','destino': 'first','fecha': 'first'})
    reindex2 = table_A.reset_index()
    table_B = pd.pivot_table(reindex2, values=['viajes'], index=["periodo"], columns=["trayecto"], aggfunc={'viajes':'first'}, fill_value=0)
    print(table_A.shape)
    print(table_B.shape)
    
    if table_B.index.shape[0] != 24:
        j = 0
        for i in range(24):
            if table_B.index[i] != (i+j):
                print (reindex.fecha.iloc[0],i+j,"origen sin registros!")
                table_B.loc[i+j] = 0
                j += 1
            if (i + j) == 23: break
        table_B = table_B.sort_index() 
    
    table_B["ds"] = pd.date_range(filtrar.fecha.iloc[0], "%s 23:00:00" % (filtrar.fecha.iloc[0]), freq="H")  #fecha.iloc[0] devuelve "20200214"-"20200215"... y la hora en formato 24h      
    table_B = table_B.set_index("ds") #Fija como indice la columna ds           
    table_B = table_B.astype(np.float32)
    
    df_Total = df_Total.append(table_B)
    df_Total = df_Total.fillna(0)       
    #break
print(df_Total.shape)
# Out:
# (558978, 7)
# (195948, 4)
# (24, 22912)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (569251, 7)
# (199095, 4)
# (24, 23108)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (551015, 7)
# (197837, 4)
# (24, 23303)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (432134, 7)
# (174171, 4)
# (24, 22526)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (339497, 7)
# (141668, 4)
# (24, 20010)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (459657, 7)
# (174135, 4)
# (24, 21625)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (475274, 7)
# (177491, 4)
# (24, 21747)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (511050, 7)
# (186084, 4)
# (24, 22282)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (532977, 7)
# (190520, 4)
# (24, 22645)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (541697, 7)
# (194173, 4)
# (24, 22828)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (431524, 7)
# (174794, 4)
# (24, 22732)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (365487, 7)
# (154716, 4)
# (24, 21747)
# /tmp/ipykernel_22315/2575003276.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (672, 32863)

# %%
reindex=filtrado_Data3.reset_index()

for fecha in serieDia3.index:   
    filtrar = reindex.loc[reindex.loc[:,'fecha'] == fecha]
    print(filtrar.shape)
    table_A = pd.pivot_table(filtrar, values=['viajes','origen','destino','fecha'], index=["periodo","trayecto"], aggfunc={'viajes':np.sum,'origen': 'first','destino': 'first','fecha': 'first'})
    reindex2 = table_A.reset_index()
    table_B = pd.pivot_table(reindex2, values=['viajes'], index=["periodo"], columns=["trayecto"], aggfunc={'viajes':'first'}, fill_value=0)
    print(table_A.shape)
    print(table_B.shape)
    
    if table_B.index.shape[0] != 24:
        j = 0
        for i in range(24):
            if table_B.index[i] != (i+j):
                print (reindex.fecha.iloc[0],i+j,"origen sin registros!")
                table_B.loc[i+j] = 0
                j += 1
            if (i + j) == 23: break
        table_B = table_B.sort_index() 
    
    table_B["ds"] = pd.date_range(filtrar.fecha.iloc[0], "%s 23:00:00" % (filtrar.fecha.iloc[0]), freq="H")  #fecha.iloc[0] devuelve "20200214"-"20200215"... y la hora en formato 24h      
    table_B = table_B.set_index("ds") #Fija como indice la columna ds           
    table_B = table_B.astype(np.float32)
    
    df_Total = df_Total.append(table_B)
    df_Total = df_Total.fillna(0)       
    #break
print(df_Total.shape)
# Out:
# (534850, 7)
# (190014, 4)
# (24, 22489)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (555335, 7)
# (195503, 4)
# (24, 22789)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (564067, 7)
# (197997, 4)
# (24, 22959)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (569727, 7)
# (199627, 4)
# (24, 23080)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (439775, 7)
# (169859, 4)
# (24, 21421)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (293812, 7)
# (133057, 4)
# (24, 19491)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (297721, 7)
# (132332, 4)
# (24, 19656)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (474618, 7)
# (176248, 4)
# (24, 21653)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (521460, 7)
# (188203, 4)
# (24, 22416)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (541993, 7)
# (193272, 4)
# (24, 22730)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (552832, 7)
# (196332, 4)
# (24, 23017)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (552229, 7)
# (197224, 4)
# (24, 23130)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (436165, 7)
# (177875, 4)
# (24, 22943)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (318752, 7)
# (142118, 4)
# (24, 20616)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (469029, 7)
# (175590, 4)
# (24, 21721)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (508512, 7)
# (185095, 4)
# (24, 22180)
# /tmp/ipykernel_22315/1660391204.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (1056, 33453)

# %%
reindex=filtrado_Data4.reset_index()

for fecha in serieDia4.index:   
    filtrar = reindex.loc[reindex.loc[:,'fecha'] == fecha]
    print(filtrar.shape)
    table_A = pd.pivot_table(filtrar, values=['viajes','origen','destino','fecha'], index=["periodo","trayecto"], aggfunc={'viajes':np.sum,'origen': 'first','destino': 'first','fecha': 'first'})
    reindex2 = table_A.reset_index()
    table_B = pd.pivot_table(reindex2, values=['viajes'], index=["periodo"], columns=["trayecto"], aggfunc={'viajes':'first'}, fill_value=0)
    print(table_A.shape)
    print(table_B.shape)
    
    if table_B.index.shape[0] != 24:
        j = 0
        for i in range(24):
            if table_B.index[i] != (i+j):
                print (reindex.fecha.iloc[0],i+j,"origen sin registros!")
                table_B.loc[i+j] = 0
                j += 1
            if (i + j) == 23: break
        table_B = table_B.sort_index() 
    
    table_B["ds"] = pd.date_range(filtrar.fecha.iloc[0], "%s 23:00:00" % (filtrar.fecha.iloc[0]), freq="H")  #fecha.iloc[0] devuelve "20200214"-"20200215"... y la hora en formato 24h      
    table_B = table_B.set_index("ds") #Fija como indice la columna ds           
    table_B = table_B.astype(np.float32)
    
    df_Total = df_Total.append(table_B)
    df_Total = df_Total.fillna(0)       
    #break
print(df_Total.shape)
# Out:
# (534131, 7)
# (191829, 4)
# (24, 22611)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (567908, 7)
# (200335, 4)
# (24, 23215)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (408062, 7)
# (166463, 4)
# (24, 21853)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (411691, 7)
# (169111, 4)
# (24, 22006)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (350168, 7)
# (150548, 4)
# (24, 21067)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (528209, 7)
# (189941, 4)
# (24, 22498)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (556005, 7)
# (197595, 4)
# (24, 22831)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (558637, 7)
# (198353, 4)
# (24, 23098)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (663827, 7)
# (218045, 4)
# (24, 24576)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (533863, 7)
# (195699, 4)
# (24, 23103)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (429653, 7)
# (177130, 4)
# (24, 22678)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (369967, 7)
# (158784, 4)
# (23, 22126)
# 2021-03-17 00:00:00 2 origen sin registros!
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (530513, 7)
# (196388, 4)
# (24, 23450)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (549145, 7)
# (201896, 4)
# (24, 23766)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (547298, 7)
# (203294, 4)
# (24, 24004)
# /tmp/ipykernel_22315/4160912050.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (1416, 33799)

# %%
reindex=filtrado_Data5.reset_index()

for fecha in serieDia5.index:   
    filtrar = reindex.loc[reindex.loc[:,'fecha'] == fecha]
    print(filtrar.shape)
    table_A = pd.pivot_table(filtrar, values=['viajes','origen','destino','fecha'], index=["periodo","trayecto"], aggfunc={'viajes':np.sum,'origen': 'first','destino': 'first','fecha': 'first'})
    reindex2 = table_A.reset_index()
    table_B = pd.pivot_table(reindex2, values=['viajes'], index=["periodo"], columns=["trayecto"], aggfunc={'viajes':'first'}, fill_value=0)
    print(table_A.shape)
    print(table_B.shape)
    
    if table_B.index.shape[0] != 24:
        j = 0
        for i in range(24):
            if table_B.index[i] != (i+j):
                print (reindex.fecha.iloc[0],i+j,"origen sin registros!")
                table_B.loc[i+j] = 0
                j += 1
            if (i + j) == 23: break
        table_B = table_B.sort_index() 
    
    table_B["ds"] = pd.date_range(filtrar.fecha.iloc[0], "%s 23:00:00" % (filtrar.fecha.iloc[0]), freq="H")  #fecha.iloc[0] devuelve "20200214"-"20200215"... y la hora en formato 24h      
    table_B = table_B.set_index("ds") #Fija como indice la columna ds           
    table_B = table_B.astype(np.float32)
    
    df_Total = df_Total.append(table_B)
    df_Total = df_Total.fillna(0)       
    #break
print(df_Total.shape)
# Out:
# (410533, 7)
# (175054, 4)
# (24, 22967)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (366850, 7)
# (155429, 4)
# (24, 21241)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (418839, 7)
# (174063, 4)
# (24, 22510)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (384294, 7)
# (164145, 4)
# (24, 22007)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (530646, 7)
# (193539, 4)
# (24, 23007)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (571841, 7)
# (200660, 4)
# (24, 23115)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (577256, 7)
# (202804, 4)
# (24, 23354)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (576257, 7)
# (201893, 4)
# (24, 23247)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (564597, 7)
# (198688, 4)
# (24, 22961)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (430148, 7)
# (170711, 4)
# (24, 21681)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (357566, 7)
# (149018, 4)
# (24, 20311)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (553332, 7)
# (195854, 4)
# (24, 22992)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (564264, 7)
# (198217, 4)
# (24, 22951)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (572803, 7)
# (200620, 4)
# (24, 23128)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (573725, 7)
# (200697, 4)
# (24, 23152)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (572791, 7)
# (202907, 4)
# (24, 23480)
# /tmp/ipykernel_22315/1491697259.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (1800, 34006)

# %%
reindex=filtrado_Data6.reset_index()

for fecha in serieDia6.index:   
    filtrar = reindex.loc[reindex.loc[:,'fecha'] == fecha]
    print(filtrar.shape)
    table_A = pd.pivot_table(filtrar, values=['viajes','origen','destino','fecha'], index=["periodo","trayecto"], aggfunc={'viajes':np.sum,'origen': 'first','destino': 'first','fecha': 'first'})
    reindex2 = table_A.reset_index()
    table_B = pd.pivot_table(reindex2, values=['viajes'], index=["periodo"], columns=["trayecto"], aggfunc={'viajes':'first'}, fill_value=0)
    print(table_A.shape)
    print(table_B.shape)
    
    if table_B.index.shape[0] != 24:
        j = 0
        for i in range(24):
            if table_B.index[i] != (i+j):
                print (reindex.fecha.iloc[0],i+j,"origen sin registros!")
                table_B.loc[i+j] = 0
                j += 1
            if (i + j) == 23: break
        table_B = table_B.sort_index() 
    
    table_B["ds"] = pd.date_range(filtrar.fecha.iloc[0], "%s 23:00:00" % (filtrar.fecha.iloc[0]), freq="H")  #fecha.iloc[0] devuelve "20200214"-"20200215"... y la hora en formato 24h      
    table_B = table_B.set_index("ds") #Fija como indice la columna ds           
    table_B = table_B.astype(np.float32)
    
    df_Total = df_Total.append(table_B)
    df_Total = df_Total.fillna(0)       
    #break
print(df_Total.shape)
# Out:
# (453493, 7)
# (183435, 4)
# (24, 23236)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (384984, 7)
# (163298, 4)
# (24, 22285)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (550351, 7)
# (195094, 4)
# (24, 22898)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (567042, 7)
# (198630, 4)
# (24, 22923)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (572242, 7)
# (200050, 4)
# (24, 23110)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (568435, 7)
# (198405, 4)
# (24, 22857)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (573539, 7)
# (202352, 4)
# (24, 23392)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (443985, 7)
# (178566, 4)
# (24, 22702)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (349691, 7)
# (147234, 4)
# (24, 20331)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (545981, 7)
# (193205, 4)
# (24, 22602)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (563949, 7)
# (198186, 4)
# (24, 22889)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (568834, 7)
# (198864, 4)
# (24, 22935)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (573251, 7)
# (200977, 4)
# (24, 23049)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (570670, 7)
# (202500, 4)
# (24, 23485)
# /tmp/ipykernel_22315/90269510.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (2136, 34113)

# %%
reindex=filtrado_Data7.reset_index()

for fecha in serieDia7.index:   
    filtrar = reindex.loc[reindex.loc[:,'fecha'] == fecha]
    print(filtrar.shape)
    table_A = pd.pivot_table(filtrar, values=['viajes','origen','destino','fecha'], index=["periodo","trayecto"], aggfunc={'viajes':np.sum,'origen': 'first','destino': 'first','fecha': 'first'})
    reindex2 = table_A.reset_index()
    table_B = pd.pivot_table(reindex2, values=['viajes'], index=["periodo"], columns=["trayecto"], aggfunc={'viajes':'first'}, fill_value=0)
    print(table_A.shape)
    print(table_B.shape)
    
    if table_B.index.shape[0] != 24:
        j = 0
        for i in range(24):
            if table_B.index[i] != (i+j):
                print (reindex.fecha.iloc[0],i+j,"origen sin registros!")
                table_B.loc[i+j] = 0
                j += 1
            if (i + j) == 23: break
        table_B = table_B.sort_index() 
    
    table_B["ds"] = pd.date_range(filtrar.fecha.iloc[0], "%s 23:00:00" % (filtrar.fecha.iloc[0]), freq="H")  #fecha.iloc[0] devuelve "20200214"-"20200215"... y la hora en formato 24h      
    table_B = table_B.set_index("ds") #Fija como indice la columna ds       
    table_B = table_B.astype(np.float32)
    
    df_Total = df_Total.append(table_B)    
    df_Total = df_Total.fillna(0)
    #break

df_Total.columns =[str(s2) for (s1,s2) in df_Total.columns.tolist()]
df_Final = df_Total.reset_index()

columns_names = df_Total.columns
with open("columns_names_confinamiento5.pickle", "wb") as file:
    pickle.dump(columns_names,file)


print(df_Final.shape)
print(columns_names.shape)
# Out:
# (401847, 7)
# (169947, 4)
# (24, 22647)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (412079, 7)
# (171878, 4)
# (24, 22667)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (402591, 7)
# (168346, 4)
# (24, 22578)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (556868, 7)
# (198625, 4)
# (24, 23273)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (581483, 7)
# (203054, 4)
# (24, 23258)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (584223, 7)
# (204074, 4)
# (24, 23457)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (585620, 7)
# (206595, 4)
# (24, 23750)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (469258, 7)
# (190012, 4)
# (24, 23729)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (377154, 7)
# (160142, 4)
# (24, 21932)
# /tmp/ipykernel_22315/4089011717.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_Total = df_Total.append(table_B)
# (2352, 34169)
# (34168,)

# %%
#df_Final.iloc[0:72,56:57000]

# %%
#hola = reindex2.loc[reindex2.loc[:,'trayecto'] == '19024-19046_AM']
#hola.head(25)

# %%
#filtrar2 = filtrar.loc[filtrar.loc[:,'periodo'] == 0]
#filtrar2.iloc[0:24,:]

# %%
df_Final.to_csv("Trayectos_Periodo_Confinamiento5.csv")
